# %% [markdown]
# | Class | Precision | Recall | F1-Score | Support |
# |-------|-----------|--------|----------|---------|
# | Soil | 0.6329 | 0.9729 | 0.7669 | 4,613,513 |
# | Bedrock | 0.3643 | 0.9396 | 0.5251 | 2,119,161 |
# | Sand | 0.7104 | 0.9858 | 0.8257 | 2,298,613 |
# | Big Rock | 0.0482 | 1.0000 | 0.0919 | 19,053 |
# | NULL | 0.9827 | 0.3980 | 0.5666 | 11,921,180 |
# | | | | | |
# | **Accuracy** | | | **0.6442** | **20,971,520** |
# | **Macro avg** | 0.5477 | 0.8593 | 0.5552 | 20,971,520 |
# | **Weighted avg** | 0.8125 | 0.6442 | 0.6344 | 20,971,520 |
#
# ------------
# ![An image](3.png)
#
# -----------

# %% [markdown]
# ![An image](vis/1.png)

# %% [markdown]
# ![An image](vis/2.png)

# %% [markdown]
# ![An image](vis/3.png)

# %% [markdown]
# ![An image](vis/4.png)

# %% [markdown]
# ![An image](vis/5.png)

# %% [markdown]
# ![An image](vis/6.png)

# %% [markdown]
# ![An image](vis/7.png)

# %% [markdown]
# ![An image](vis/8.png)

# %% [markdown]
# ![An image](vis/9.png)

# %% [markdown]
# ![An image](vis/10.png)

# %% [markdown]
# ![An image](vis/11.png)

# %% [markdown]
# link for the model : https://drive.google.com/file/d/1Vy9OhmEhuM5yTDxSth9xqlHRNpcIVBC8/view?usp=drive_link
